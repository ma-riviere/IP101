# %% [markdown]
# ***
# # TP5 : Segmentation d'image
# ***

# %% [markdown]
# L’objectif de ce TP consiste à analyser des objets extraits d’une image par segmentation en régions. Les objets traités sont des cellules.
# La segmentation d’une image consiste à isoler les différents objets présents dans une image.

# %% [markdown]
# ## I. segmentation avec Binarization, labeling

# %% [markdown]
# Pour binariser une image, nous allons d'abord tracer l'histogramme des deux images pour nous aider à décider de la
# seuil.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pimg
# %matplotlib inline
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.ndimage.measurements import label

# %%
from skimage import img_as_ubyte
img = plt.imread('img/cellules.png')
img=img_as_ubyte(img)
plt.title("Image original")
plt.imshow(img, cmap='Greys_r')

# %% [markdown]
# À partir des images d'origine et des histogrammes, nous pouvons découvrir que les cellules ont une échelle de gris élevée.
# valeur. Comparées à d'autres parties de l'image, les cellules ont une surface relativement petite. Donc,
# permet de choisir le seuil = 125 pour binariser l'image.

# %% [markdown]
# ### **[Exercice 1]** A vous de jouer:
# 1. analysez l'histogramme de l'image pour choisir le niveau de gris qui permettre à changer le color des cellules en balanc.
# 2. Utilisez le niveau de gris selectionnée pour segmenter l'image de deux niveaux de gris (noir pour le fond et blanc pour les cellules
# 3. Visualisez l'image de segmentation
# 4. Developez une method qui permettre a compter le nombre des cellules automatiquement.

# %%
# > Emplacement exercice <

# %% [markdown]
# ## II. Segmentation avec les k-means

# %% [markdown]
# Les  K-means sont une méthode d’apprentissage non supervisé permettant de trouver des  groupes parmi un nuage de points. On peut la résumer ainsi:
#
# ```
# Données:  Un ensemble de E de points de l’espace, K,  un  entier  désignant  le  nombre  de  groupes  que  l’on souhaite faire
#
# 1. Soit N un ensemble de k points placés au hasard dans l’espace
#
# 2. Associer  chaque  point  de  E  au  point  de  N  qui  lui  est  le  plus proche
#
# 3. Déplacer chaque point de N surle barycentre des points de E qui lui sont associés
#
# 4. Répéter les étapes 2-4 jusqu’à stabilité des points de N
# ```

# %% [markdown]
# ### **[Exercice 2]** A vous de jouer:
#
# 1. écrivez la fonction qui segment l'image en région cohéron en utilisant la méthod de l'apprentissage non-superviser de k-means intorduit précedament.
# 2. Visualisez l'image en sortie de la fonction de segmentation avec les k-means, en fixant le parametre k à 2 pour segmenter l'image des cellules en deux niveau de gris
#
# **vous pouvez vous en servire de code python déjà exist sur le github:**
#
# https://github.com/asselinpaul/ImageSeg-KMeans

# %%
# > Emplacement exercice <
